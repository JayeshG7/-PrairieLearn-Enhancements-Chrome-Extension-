# %%
import bs4 as soup
import selenium
# Out:
# Running cells with 'Python 3.9.18 ('pl_enhancements')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n pl_enhancements ipykernel --update-deps --force-reinstall'
